# %% [markdown]
# ### Daum Exchange
# - 환율정보 수집
# - headers : referer, user-agent
# - https://finance.daum.net/exchanges

# %%
import pandas as pd
import requests

# %%
url = "https://finance.daum.net/api/exchanges/summaries"

# %%
headers = {
    "user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/103.0.0.0 Safari/537.36",
    "referer": "https://finance.daum.net/exchanges",
}

# %%
response = requests.get(url, headers=headers)
response
# Out:
# <Response [200]>

# %%
data = response.json()["data"]
df = pd.DataFrame(data)[["symbolCode", "currencyCode", "basePrice"]]
df
# Out:
#     symbolCode currencyCode  basePrice
# 0   FRX.KRWUSD          USD    1311.80
# 1   FRX.KRWJPY          JPY     980.38
# 2   FRX.KRWCNY          CNY     194.00
# 3   FRX.KRWEUR          EUR    1333.31
# 4   FRX.KRWGBP          GBP    1593.97
# 5   FRX.KRWCHF          CHF    1364.33
# 6   FRX.KRWCAD          CAD    1021.05
# 7   FRX.KRWNZD          NZD     824.99
# 8   FRX.KRWHKD          HKD     167.12
# 9   FRX.KRWBRL          BRL     248.26
# 10  FRX.KRWMXN          MXN      64.08
# 11  FRX.KRWAED          AED     357.14
# 12  FRX.KRWKWD          KWD    4275.47
# 13  FRX.KRWBHD          BHD    3479.58
# 14  FRX.KRWINR          INR      16.51
# 15  FRX.KRWSAR          SAR     348.88
# 16  FRX.KRWNOK          NOK     135.09
# 17  FRX.KRWDKK          DKK     179.14
# 18  FRX.KRWMYR          MYR     294.51
# 19  FRX.KRWBDT          BDT      13.85
# 20  FRX.KRWPKR          PKR       5.88
# 21  FRX.KRWIDR          IDR       8.81
# 22  FRX.KRWTWD          TWD      43.68
# 23  FRX.KRWPHP          PHP      23.54
# 24  FRX.KRWSEK          SEK     128.44
# 25  FRX.KRWAUD          AUD     912.29
# 26  FRX.KRWSGD          SGD     950.13
# 27  FRX.KRWTHB          THB      36.26
# 28  FRX.KRWEGP          EGP      68.75
# 29  FRX.KRWBND          BND     950.13
# 30  FRX.KRWILS          ILS     390.88
# 31  FRX.KRWJOD          JOD    1850.21
# 32  FRX.KRWVND          VND       5.60
# 33  FRX.KRWRUB          RUB      21.71
# 34  FRX.KRWHUF          HUF       3.38
# 35  FRX.KRWPLN          PLN     283.79
# 36  FRX.KRWZAR          ZAR      78.26
# 37  FRX.KRWMNT          MNT       0.41
# 38  FRX.KRWCZK          CZK      54.10
# 39  FRX.KRWKZT          KZT       2.75
# 40  FRX.KRWQAR          QAR     358.12
# 41  FRX.KRWTRY          TRY      73.09
